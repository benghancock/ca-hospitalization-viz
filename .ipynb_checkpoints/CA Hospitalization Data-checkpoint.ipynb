# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import ca_hospitals_data

# %matplotlib inline

# %%
data = ca_hospitals_data.get_county("San Francisco")
# Out:
# INFO:root:Got 50 results out of 106 ...
# INFO:root:Got 100 results out of 106 ...
# INFO:root:Got 106 results out of 106 ...
# INFO:root:Collected all pages

# %%
df = pd.DataFrame(data.get("series"))

# %%
df.head()
# Out:
#    _id  all_hospital_beds         county  \
# 0   97                NaN  San Francisco
# 1  150                NaN  San Francisco
# 2  205                NaN  San Francisco
# 3  257                NaN  San Francisco
# 4  312                NaN  San Francisco
#
#    hospitalized_covid_confirmed_patients  hospitalized_covid_patients  \
# 0                                   58.0                          NaN
# 1                                   67.0                          NaN
# 2                                   67.0                          NaN
# 3                                   75.0                          NaN
# 4                                   80.0                          NaN
#
#    hospitalized_suspected_covid_patients  icu_available_beds  \
# 0                                   92.0                90.0
# 1                                   69.0                77.0
# 2                                   66.0                64.0
# 3                                   60.0                58.0
# 4                                   71.0                74.0
#
#    icu_covid_confirmed_patients  icu_suspected_covid_patients      rank  \
# 0                          18.0                           7.0  0.090167
# 1                          30.0                          14.0  0.090167
# 2                          30.0                           8.0  0.090167
# 3                          32.0                          11.0  0.090167
# 4                          39.0                           8.0  0.090167
#
#            todays_date
# 0  2020-03-30T00:00:00
# 1  2020-03-31T00:00:00
# 2  2020-04-01T00:00:00
# 3  2020-04-02T00:00:00
# 4  2020-04-03T00:00:00

# %%
# Convert the date values to datetime type
df["todays_date"] = pd.to_datetime(
    df["todays_date"], infer_datetime_format=True
)

# Sort and set the date as the index
df = df.sort_values("todays_date").set_index("todays_date")
             
df.head()
# Out:
#              _id  all_hospital_beds         county  \
# todays_date
# 2020-03-29    12                NaN  San Francisco
# 2020-03-30    97                NaN  San Francisco
# 2020-03-31   150                NaN  San Francisco
# 2020-04-01   205                NaN  San Francisco
# 2020-04-02   257                NaN  San Francisco
#
#              hospitalized_covid_confirmed_patients  \
# todays_date
# 2020-03-29                                    50.0
# 2020-03-30                                    58.0
# 2020-03-31                                    67.0
# 2020-04-01                                    67.0
# 2020-04-02                                    75.0
#
#              hospitalized_covid_patients  \
# todays_date
# 2020-03-29                           NaN
# 2020-03-30                           NaN
# 2020-03-31                           NaN
# 2020-04-01                           NaN
# 2020-04-02                           NaN
#
#              hospitalized_suspected_covid_patients  icu_available_beds  \
# todays_date
# 2020-03-29                                    73.0                61.0
# 2020-03-30                                    92.0                90.0
# 2020-03-31                                    69.0                77.0
# 2020-04-01                                    66.0                64.0
# 2020-04-02                                    60.0                58.0
#
#              icu_covid_confirmed_patients  icu_suspected_covid_patients  \
# todays_date
# 2020-03-29                           24.0                          10.0
# 2020-03-30                           18.0                           7.0
# 2020-03-31                           30.0                          14.0
# 2020-04-01                           30.0                           8.0
# 2020-04-02                           32.0                          11.0
#
#                  rank
# todays_date
# 2020-03-29   0.090167
# 2020-03-30   0.090167
# 2020-03-31   0.090167
# 2020-04-01   0.090167
# 2020-04-02   0.090167

# %%
sf_confirmed = df[['hospitalized_covid_confirmed_patients']]
sf_confirmed.head(10)
# Out:
#              hospitalized_covid_confirmed_patients
# todays_date
# 2020-03-29                                    50.0
# 2020-03-30                                    58.0
# 2020-03-31                                    67.0
# 2020-04-01                                    67.0
# 2020-04-02                                    75.0
# 2020-04-03                                    80.0
# 2020-04-04                                    80.0
# 2020-04-05                                    79.0
# 2020-04-06                                    80.0
# 2020-04-07                                    88.0

# %%
sf_confirmed.rolling('7D').mean().head(10)
# Out:
#              hospitalized_covid_confirmed_patients
# todays_date
# 2020-03-29                               50.000000
# 2020-03-30                               54.000000
# 2020-03-31                               58.333333
# 2020-04-01                               60.500000
# 2020-04-02                               63.400000
# 2020-04-03                               66.166667
# 2020-04-04                               68.142857
# 2020-04-05                               72.285714
# 2020-04-06                               75.428571
# 2020-04-07                               78.428571

# %%
fig, ax = plt.subplots(figsize=(12, 6))

plt.style.use("seaborn-deep")
plt.bar(x=sf_confirmed.index, height=sf_confirmed["hospitalized_covid_confirmed_patients"])
plt.plot(sf_confirmed.rolling('7D').mean(), color='orange')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
